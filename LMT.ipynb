# %% [markdown]
# # LMT - Time Series Analysis
#
# Following [this tutorial](https://medium.datadriveninvestor.com/how-to-create-time-series-analysis-of-stocks-using-python-59646dc54311) to see how the Lockheed Martin (NYSE:LMT) has been performing!

# %%
import yfinance as yf       # to get data
lmt = yf.Ticker("LMT")
lmt.financials
# Out:
#                                            2021-12-31     2020-12-31  \
# Research Development                             None           None
# Effect Of Accounting Charges                     None           None
# Income Before Tax                        7550000000.0   8235000000.0
# Minority Interest                                 NaN     23000000.0
# Net Income                               6315000000.0   6833000000.0
# Selling General Administrative           1241000000.0   -241000000.0
# Gross Profit                             9097000000.0   8681000000.0
# Ebit                                     7821000000.0   8877000000.0
# Operating Income                         7821000000.0   8877000000.0
# Other Operating Expenses                   35000000.0     45000000.0
# Interest Expense                         -569000000.0   -591000000.0
# Extraordinary Items                              None           None
# Non Recurring                                    None           None
# ...
